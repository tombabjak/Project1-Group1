# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import datetime as dt
from scipy.stats import linregress
impact_on_employment = "Impact on Employment.csv"
impact_employment_df = pd.read_csv(impact_on_employment)
impact_employment_df.head()
# Out:
#   week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 0  1/16/2021            1/9/2021  04000US08    Colorado           13728
# 1  1/16/2021            1/9/2021  04000US22   Louisiana           15424
# 2  1/16/2021            1/9/2021  04000US27   Minnesota           13680
# 3  1/16/2021            1/9/2021  04000US34  New Jersey           14046
# 4  1/16/2021            1/9/2021  04000US55   Wisconsin           16965
#
#    continued_claims  covered_employment  insured_unemployment_rate  \
# 0             93383                   0                        0.0
# 1             59881                   0                        0.0
# 2            143829                   0                        0.0
# 3            143660                   0                        0.0
# 4            107132                   0                        0.0
#
#       Timestamp                Date ID Geography   Geography
# 0  1.610770e+12  January 16th, 2021    04000US08    Colorado
# ...

# %%
bitcoin_open = impact_employment_df["continued_claims"].max()
bitcoin_open
# Out:
# 715433

# %%
impact_employment_df['week_ended'
]= pd.DatetimeIndex(impact_employment_df['week_ended'
]).strftime('%Y-%m')
impact_employment_df.head()
# Out:
#   week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 0    2021-01            1/9/2021  04000US08    Colorado           13728
# 1    2021-01            1/9/2021  04000US22   Louisiana           15424
# 2    2021-01            1/9/2021  04000US27   Minnesota           13680
# 3    2021-01            1/9/2021  04000US34  New Jersey           14046
# 4    2021-01            1/9/2021  04000US55   Wisconsin           16965
#
#    continued_claims  covered_employment  insured_unemployment_rate  \
# 0             93383                   0                        0.0
# 1             59881                   0                        0.0
# 2            143829                   0                        0.0
# 3            143660                   0                        0.0
# 4            107132                   0                        0.0
#
#       Timestamp                Date ID Geography   Geography   datetime  year
# ...

# %%
state_nj = impact_employment_df.loc[impact_employment_df["state_name"
] == "New Jersey", :].sort_values("week_ended", ascending=True)
state_nj.head()
# Out:
#     week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 793    2018-01          12/30/2017  04000US34  New Jersey           16190
# 778    2018-01           1/20/2018  04000US34  New Jersey            8981
# 788    2018-01            1/6/2018  04000US34  New Jersey           15040
# 783    2018-01           1/13/2018  04000US34  New Jersey           10806
# 758    2018-02           2/17/2018  04000US34  New Jersey            7908
#
#      continued_claims  covered_employment  insured_unemployment_rate  \
# 793            113263             3920147                       2.89
# 778            118337             3934397                       3.01
# 788            121653             3934397                       3.09
# 783            116061             3934397                       2.95
# 758            113829             3934397                       2.89
#
#         Timestamp                 Date ID Geography   Geography   datetime  \
# ...

# %%
state_nj = impact_employment_df.loc[impact_employment_df["state_name"] == "New Jersey", 
:].sort_values("week_ended", ascending=True)
state_nj.head()
# Out:
#     week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 793    2018-01          12/30/2017  04000US34  New Jersey           16190
# 778    2018-01           1/20/2018  04000US34  New Jersey            8981
# 788    2018-01            1/6/2018  04000US34  New Jersey           15040
# 783    2018-01           1/13/2018  04000US34  New Jersey           10806
# 758    2018-02           2/17/2018  04000US34  New Jersey            7908
#
#      continued_claims  covered_employment  insured_unemployment_rate  \
# 793            113263             3920147                       2.89
# 778            118337             3934397                       3.01
# 788            121653             3934397                       3.09
# 783            116061             3934397                       2.95
# 758            113829             3934397                       2.89
#
#         Timestamp                 Date ID Geography   Geography   datetime  \
# ...

# %%
year = state_nj.iloc[:,0]
continued_claims = state_nj.iloc[:,5]
plt.scatter(year,continued_claims)
plt.xticks(year, rotation=90)
plt.xlabel('Year')
plt.ylabel('Continued Claims')
plt.show()

# %%
year = state_nj.iloc[:,0]
continued_claims = state_nj.iloc[:,5]
plt.scatter(year,continued_claims)
plt.xticks(year, rotation=90)
plt.xlabel('Year')
plt.ylabel('covered_employment')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
state_nj_test = state_nj['week_ended'] = pd.DatetimeIndex(state_nj['week_ended']).year
state_nj_test = state_nj
state_nj_test
# Out:
#      week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 793        2018          12/30/2017  04000US34  New Jersey           16190
# 778        2018           1/20/2018  04000US34  New Jersey            8981
# 788        2018            1/6/2018  04000US34  New Jersey           15040
# 783        2018           1/13/2018  04000US34  New Jersey           10806
# 758        2018           2/17/2018  04000US34  New Jersey            7908
# ..          ...                 ...        ...         ...             ...
# 23         2020          12/12/2020  04000US34  New Jersey           17611
# 18         2020          12/19/2020  04000US34  New Jersey           20462
# 13         2021          12/26/2020  04000US34  New Jersey           20988
# 8          2021            1/2/2021  04000US34  New Jersey           21836
# 3          2021            1/9/2021  04000US34  New Jersey           14046
#
# ...

# %%
year = state_nj_test.iloc[:,0]
continued_claims = state_nj_test.iloc[:,5]
plt.scatter(year,continued_claims)
plt.xticks(year, rotation=90)
plt.xlabel('Year')
plt.ylabel('Continued Claims')
plt.show()

# %%
continued_claims
# Out:
# 793    113263
# 778    118337
# 788    121653
# 783    116061
# 758    113829
#         ...
# 23     146200
# 18     138261
# 13     141210
# 8      156368
# 3      143660
# Name: continued_claims, Length: 159, dtype: int64

# %%
#dt = datetime.strptime("21/11/06 16:30", "%d/%m/%y %H:%M")

# %%
dt.datetime.strptime("31/1/2019","%d/%m/%Y")
# Out:
# datetime.datetime(2019, 1, 31, 0, 0)

# %%
df = pd.DataFrame({"date":["1/15/2020","2/25/2020","5/23/2020"],"values":[2,6,8]})
df
# Out:
#         date  values
# 0  1/15/2020       2
# 1  2/25/2020       6
# 2  5/23/2020       8

# %%
state_nj['datetime'
] = pd.to_datetime(impact_employment_df['week_ended'
],format="%Y/%m")
state_nj
# Out:
#     week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 793    2018-01          12/30/2017  04000US34  New Jersey           16190
# 778    2018-01           1/20/2018  04000US34  New Jersey            8981
# 788    2018-01            1/6/2018  04000US34  New Jersey           15040
# 783    2018-01           1/13/2018  04000US34  New Jersey           10806
# 758    2018-02           2/17/2018  04000US34  New Jersey            7908
# ..         ...                 ...        ...         ...             ...
# 23     2020-12          12/12/2020  04000US34  New Jersey           17611
# 18     2020-12          12/19/2020  04000US34  New Jersey           20462
# 13     2021-01          12/26/2020  04000US34  New Jersey           20988
# 8      2021-01            1/2/2021  04000US34  New Jersey           21836
# 3      2021-01            1/9/2021  04000US34  New Jersey           14046
#
#      continued_claims  covered_employment  insured_unemployment_rate  \
# ...

# %%
impact_employment_df['year'] = impact_employment_df['datetime'].map(lambda y: y.year)
impact_employment_df
# Out:
#     week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 0      2021-01            1/9/2021  04000US08    Colorado           13728
# 1      2021-01            1/9/2021  04000US22   Louisiana           15424
# 2      2021-01            1/9/2021  04000US27   Minnesota           13680
# 3      2021-01            1/9/2021  04000US34  New Jersey           14046
# 4      2021-01            1/9/2021  04000US55   Wisconsin           16965
# ..         ...                 ...        ...         ...             ...
# 790    2018-01          12/30/2017  04000US08    Colorado            3095
# 791    2018-01          12/30/2017  04000US22   Louisiana            2221
# 792    2018-01          12/30/2017  04000US27   Minnesota            8783
# 793    2018-01          12/30/2017  04000US34  New Jersey           16190
# 794    2018-01          12/30/2017  04000US55   Wisconsin           15298
#
#      continued_claims  covered_employment  insured_unemployment_rate  \
# ...

# %%
start_date = "2018-01-01"
end_date = "2018-12-31"
after_start_date = state_nj["datetime"] >= start_date
before_end_date = state_nj["datetime"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_2018 = state_nj.loc[between_two_dates
].sort_values("week_ended", ascending=True)
filtered_dates_2018.head()
# Out:
#     week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 793    2018-01          12/30/2017  04000US34  New Jersey           16190
# 778    2018-01           1/20/2018  04000US34  New Jersey            8981
# 788    2018-01            1/6/2018  04000US34  New Jersey           15040
# 783    2018-01           1/13/2018  04000US34  New Jersey           10806
# 758    2018-02           2/17/2018  04000US34  New Jersey            7908
#
#      continued_claims  covered_employment  insured_unemployment_rate  \
# 793            113263             3920147                       2.89
# 778            118337             3934397                       3.01
# 788            121653             3934397                       3.09
# 783            116061             3934397                       2.95
# 758            113829             3934397                       2.89
#
#         Timestamp                 Date ID Geography   Geography   datetime  \
# ...

# %%
year = filtered_dates_2018.iloc[:,0]
continued_claims = filtered_dates_2018.iloc[:,5]
plt.scatter(year,continued_claims)
plt.xticks(year, rotation=90)
plt.xlabel('Year')
plt.ylabel('Unemployment Claims')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# x_values = impact_employment_df['week_ended']
# y_values = impact_employment_df['continued_claims']
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(x_values,y_values)
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(0,50),fontsize=15,color="red")
# plt.xlabel('Year-Month')
# plt.ylabel('Employment Coverage')
# print(f"The r-squared is: {rvalue**2}")
# plt.show()

# %%
start_date = "2019-01-01"
end_date = "2019-12-31"

after_start_date = state_nj["datetime"] >= start_date
before_end_date = state_nj["datetime"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_2019 = state_nj.loc[between_two_dates].sort_values("week_ended", ascending=True)
filtered_dates_2019.head()
# Out:
#     week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 518    2019-01           1/19/2019  04000US34  New Jersey           11130
# 528    2019-01            1/5/2019  04000US34  New Jersey           14167
# 533    2019-01          12/29/2018  04000US34  New Jersey           15716
# 523    2019-01           1/12/2019  04000US34  New Jersey           10190
# 513    2019-02           1/26/2019  04000US34  New Jersey            9903
#
#      continued_claims  covered_employment  insured_unemployment_rate  \
# 518            108219             3977393                       2.72
# 528            110669             3977393                       2.78
# 533            108647             3967985                       2.74
# 523            106096             3977393                       2.67
# 513            111749             3977393                       2.81
#
#         Timestamp                Date ID Geography   Geography   datetime  \
# ...

# %%
year = filtered_dates_2019.iloc[:,0]
continued_claims = filtered_dates_2019.iloc[:,5]
plt.scatter(year,continued_claims)
plt.xticks(year, rotation=90)
plt.xlabel('Year')
plt.ylabel('Unemployment Claims')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
start_date = "2020-01-01"
end_date = "2020-12-31"

after_start_date = state_nj["datetime"] >= start_date
before_end_date = state_nj["datetime"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_2020 = state_nj.loc[between_two_dates].sort_values("week_ended", ascending=True)
filtered_dates_2020.head()
# Out:
#     week_ended reflecting_week_end  fips_code  state_name  initial_claims  \
# 273    2020-01          12/28/2019  04000US34  New Jersey           15325
# 268    2020-01            1/4/2020  04000US34  New Jersey           13469
# 263    2020-01           1/11/2020  04000US34  New Jersey           10728
# 258    2020-01           1/18/2020  04000US34  New Jersey            9325
# 233    2020-02           2/22/2020  04000US34  New Jersey            7773
#
#      continued_claims  covered_employment  insured_unemployment_rate  \
# 273            111335             4007202                       2.78
# 268            120461             4015146                       3.00
# 263            108425             4015146                       2.70
# 258            107082             4015146                       2.67
# 233            110902             4015146                       2.76
#
#         Timestamp                 Date ID Geography   Geography   datetime  \
# ...

# %%
year = filtered_dates_2020.iloc[:,0]
continued_claims = filtered_dates_2020.iloc[:,5]
year.plot(grid=True)
plt.scatter(year,continued_claims)
plt.xticks(year, rotation=90)
plt.xlabel('Year')
plt.ylabel('Unemployment Claims')
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-0250b46420c7> in <module>
#       1 year = filtered_dates_2020.iloc[:,0]
#       2 continued_claims = filtered_dates_2020.iloc[:,5]
# ----> 3 year.plot(grid=True)
#       4 plt.scatter(year,continued_claims)
#       5 plt.xticks(year, rotation=90)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
# ...

# %%
# x_values = impact_employment_df['week_ended']
# y_values = impact_employment_df['continued_claims']
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(x_values,y_values)
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")
# plt.xlabel('Rooms in House')
# plt.ylabel('Median House Prices ($1000)')
# print(f"The r-squared is: {rvalue**2}")
# plt.show()

# %%
year_2018 = filtered_dates_2018.dropna(how='any')
ax2 = year_2018.plot(kind ="line", x= 'week_ended', y = 'continued_claims', label='2018')
plt.xticks((0,len(years['week_ended']),2),rotation=45)
plt.ylabel("Unemployment Claims")
plt.xlabel("Year 2018")
plt.show
# x_values = impact_employment_df['week_ended']
# y_values = impact_employment_df['continued_claims']
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
year_2019 = filtered_dates_2018.dropna(how='any')
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(year_2018['week_ended'], year_2018['continued_claims'],
        color='purple')

# %%
filtered_dates_2018.plot(x="week_ended", 
y = "continued_claims", label='2018',
grid=True,title= "NJ Unemployment Claims for the Year 2018",
color='green')
plt.xlim(0,60)
plt.ylabel("Unemployment Claims")
plt.xlabel("Year-Month")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
year_2019 = filtered_dates_2019.dropna(how='any')
ax2 = year_2019.plot(kind ="line", x= 'week_ended', y = 'continued_claims', label='2019',grid=True)
plt.xticks((0,len(years['week_ended']),2),rotation=45)
plt.ylabel("Unemployment Claims")
plt.xlabel("Year 2019")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
filtered_dates_2019.plot(x="week_ended", y = "continued_claims", 
label='2019',grid=True,title= "NJ Unemployment Claims for the Year 2019"
,color='purple')
plt.xlim(0,60)
plt.ylabel("Unemployment Claims")
plt.xlabel("Year-Month")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# year_2019 = filtered_dates_2019.dropna(how='any')
# fig, ax = plt.subplots(figsize=(10, 10))
# ax.plot(year_2019['week_ended'], year_2019['continued_claims'],
#         color='purple')

# %%
year_2020 = filtered_dates_2020.dropna(how='any')
ax2 = year_2020.plot(kind ="line", x= 'week_ended', y = 'continued_claims', label='2020')
plt.xticks((0,len(years['week_ended']),2),rotation=45)
plt.ylabel("Unemployment Claims")
plt.xlabel("Year 2020")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
filtered_dates_2020.plot(x="week_ended", y = "continued_claims", label='2020',grid=True, title= "NJ Unemployment Claims for the Year 2020")
plt.xlim(0,65)
plt.ylabel("Unemployment Claims")
plt.xlabel("Year-Month")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
filtered_dates_2020.plot(kind="scatter", x="week_ended", y="continued_claims", grid=True, figsize=(8,8),
              title="MPG Vs. Horsepower")
plt.show()

# %%
year_2020 = filtered_dates_2020.dropna(how='any')
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(year_2020['week_ended'], year_2020['continued_claims'],
        color='purple',label='2020')

# %%
year_20 = impact_employment_df.dropna(how='any')
ax2 = year_20.plot(kind ="line", x= 'week_ended', y = 'continued_claims', label='2019')
plt.xticks((0,len(years['week_ended']),2),rotation=45)
plt.ylabel("Unemployment Claims")
plt.xlabel("Year 2019")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
